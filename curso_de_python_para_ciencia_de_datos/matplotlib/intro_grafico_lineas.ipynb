# %%
import numpy as np
import matplotlib.pyplot as plt

month = np.array(['E', 'F', 'M', 'J', 'S'])
sales = np.array([20, 25, 30, 28, 35])

# Configurar el tamaño del grafico
plt.figure(figsize=(8, 6))

# Crear el grafico
plt.plot(month, sales, marker='o', color='blue')

plt.title('Ventas mensuales de un producto')
plt.xlabel('Meses')
plt.ylabel('Ventas en miles de unidades')
# Out:
# Text(0, 0.5, 'Ventas en miles de unidades')

# %%
import matplotlib.pyplot as plt

# Configurar el tamano del grafico 
plt.figure(figsize=(8, 6))

# %%
hours = [2,3,4,5,6,7,8]
exam = [55,60,65,70,75,80,85]

plt.scatter(hours, exam, color='green')
plt.title('Relacion entre horas enstudiadas y puntaje')
plt.xlabel('Horas')
plt.ylabel('Puntaje')

plt.show()
